# %%
import pandas as pd
df = pd.read_csv("co2/co2_data.csv")

# %%
df.info
# Out:
# <bound method DataFrame.info of         Unnamed: 0  year  month  day  hour  minute  second  \
# 0                0  1975      7   24     4       0       0
# 1                1  1975      7   24     5       0       0
# 2                2  1975      7   24     6       0       0
# 3                3  1975      7   24     7       0       0
# 4                4  1975      7   24     8       0       0
# ...            ...   ...    ...  ...   ...     ...     ...
# 430153      430153  2024      8   18     5       0       0
# 430154      430154  2024      8   18     6       0       0
# 430155      430155  2024      8   18     7       0       0
# 430156      430156  2024      8   18     8       0       0
# 430157      430157  2024      8   18     9       0       0
#
#                    datetime   value  value_std_dev  value_unc  nvalue  \
# 0       1975-07-24 04:00:00     NaN            NaN        NaN       0
# 1       1975-07-24 05:00:00     NaN            NaN        NaN       0
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  year  month  day  hour  minute  second             datetime  \
# 0           0  1975      7   24     4       0       0  1975-07-24 04:00:00
# 1           1  1975      7   24     5       0       0  1975-07-24 05:00:00
# 2           2  1975      7   24     6       0       0  1975-07-24 06:00:00
# 3           3  1975      7   24     7       0       0  1975-07-24 07:00:00
# 4           4  1975      7   24     8       0       0  1975-07-24 08:00:00
#
#    value  value_std_dev  value_unc  nvalue instrument qcflag
# 0    NaN            NaN        NaN       0      UN2-2    *..
# 1    NaN            NaN        NaN       0      UN2-2    *..
# 2    NaN            NaN        NaN       0      UN2-2    *..
# 3    NaN            NaN        NaN       0      UN2-2    *..
# 4    NaN            NaN        NaN       0      UN2-2    *..

# %%
ef = df[["day", "value", "instrument", "qcflag", "year"]]

# %%
cd = pd.read_csv("dataset meteo\meteo_dataset.csv")
cd.head(20)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\yayahearts\AppData\Local\Temp\ipykernel_12740\1454331038.py:1: SyntaxWarning: invalid escape sequence '\m'
#   cd = pd.read_csv("dataset meteo\meteo_dataset.csv")
#     Unnamed: 0  synoptical station index  year (Greenwich)  month (Greenwich)  \
# 0            0                     27459              1990                  1
# 1            1                     27459              1990                  1
# 2            2                     27459              1990                  1
# 3            3                     27459              1990                  1
# 4            4                     27459              1990                  1
# 5            5                     27459              1990                  1
# 6            6                     27459              1990                  1
# ...

# %%
cd[["year (Greenwich)"]].value_counts()
# Out:
# year (Greenwich)
# 2008                2928
# 1992                2928
# 2012                2928
# 2020                2928
# 1996                2928
# 2004                2928
# 2000                2928
# 2016                2928
# 2015                2920
# 2011                2920
# 2013                2920
# 2014                2920
# 1990                2920
# 2010                2920
# 2018                2920
# 2019                2920
# 2021                2920
# 2022                2920
# 2017                2920
# 2007                2920
# 2009                2920
# 1991                2920
# 2006                2920
# 2005                2920
# 2003                2920
# 2002                2920
# 2001                2920
# 1999                2920
# 1998                2920
# 1997                2920
# 1995                2920
# 1994                2920
# 1993                2920
# 2023                2918
# Name: count, dtype: int64

# %%
rt = cd[["year (Greenwich)", "month (Greenwich)", "day (Greenwich)", "term (Greenwich)", "total cloud cover", "wind direction", "average wind speed", "total precipitation", "air temperature (dry termometer)", "relative air humidity", "atmospheric pressure (station level)"]]
rt.head()
# Out:
#    year (Greenwich)  month (Greenwich)  day (Greenwich)  term (Greenwich)  \
# 0              1990                  1                1                 0
# 1              1990                  1                1                 3
# 2              1990                  1                1                 6
# 3              1990                  1                1                 9
# 4              1990                  1                1                12
#
#    total cloud cover  wind direction  average wind speed  total precipitation  \
# 0               10.0           270.0                 5.0                  0.0
# 1               10.0           280.0                 5.0                  0.0
# 2                9.0           290.0                 4.0                  0.0
# 3               12.0           300.0                 6.0                  0.0
# 4               12.0           300.0                 5.0                  0.0
#
# ...

# %%
import datetime
rt["datetime"] = [datetime.datetime(y, m, d, h) + datetime.timedelta(hours = 4) for y, m, d, h in zip(
    rt["year (Greenwich)"], rt["month (Greenwich)"], rt["day (Greenwich)"], rt["term (Greenwich)"]
)]
rt.head(12)
# Out:
# C:\Users\yayahearts\AppData\Local\Temp\ipykernel_12740\2060539716.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rt["datetime"] = [datetime.datetime(y, m, d, h) + datetime.timedelta(hours = 4) for y, m, d, h in zip(
#     year (Greenwich)  month (Greenwich)  day (Greenwich)  term (Greenwich)  \
# 0               1990                  1                1                 0
# 1               1990                  1                1                 3
# 2               1990                  1                1                 6
# 3               1990                  1                1                 9
# 4               1990                  1                1                12
# ...

# %%
rt.index = rt["datetime"]
rt['date'] = pd.to_datetime(
    dict(year=rt["year (Greenwich)"], month=rt[""], day=rt["day (Greenwich)"])
)
rt = rt.drop(["year (local)", "month (local)", "day (local)", "local time", "datetime"], axis=1)

rt.head()
# Out:
# C:\Users\yayahearts\AppData\Local\Temp\ipykernel_12740\4176970166.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rt['date'] = pd.to_datetime(
#                      total cloud cover  wind direction  average wind speed  \
# datetime
# 1990-01-01 04:00:00               10.0           270.0                 5.0
# 1990-01-01 07:00:00               10.0           280.0                 5.0
# 1990-01-01 10:00:00                9.0           290.0                 4.0
# 1990-01-01 13:00:00               12.0           300.0                 6.0
# 1990-01-01 16:00:00               12.0           300.0                 5.0
#
#                      total precipitation  air temperature (dry termometer)  \
# datetime
# ...

# %%
rt.info()

# %%
dtt = rt
dtt = dtt.dropna(axis=0)
dtt.head()
dtt.shape
# Out:
# (97349, 8)

# %%
df = pd.read_csv("meteo_notNaN_TRUE.csv")
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  year (local)  month (local)  day (local)  \
# 0          7054        7054          1992              6            1
# 1          7055        7055          1992              6            1
# 2          7056        7056          1992              6            1
# 3          7057        7057          1992              6            1
# 4          7058        7058          1992              6            1
#
#    local time  total cloud cover  weather between time  wind direction  \
# 0          22                7.0                   2.0           240.0
# 1           1                6.0                   2.0            90.0
# 2           4               10.0                   2.0           180.0
# 3           7                8.0                   2.0           300.0
# 4          10                8.0                   2.0           230.0
#
#    average wind speed  total precipitation  air temperature (dry termometer)  \
# ...

# %%
import datetime

df["datetime"] = [datetime.datetime(y, m, d, h) for y, m, d, h in zip(
    df["year (local)"], df["month (local)"], df["day (local)"], df["local time"]
)]

# %%
df.head(12)
# Out:
#     Unnamed: 0.1  Unnamed: 0  year (local)  month (local)  day (local)  \
# 0           7054        7054          1992              6            1
# 1           7055        7055          1992              6            1
# 2           7056        7056          1992              6            1
# 3           7057        7057          1992              6            1
# 4           7058        7058          1992              6            1
# 5           7059        7059          1992              6            1
# 6           7060        7060          1992              6            1
# 7           7061        7061          1992              6            1
# 8           7062        7062          1992              6            2
# 9           7063        7063          1992              6            2
# 10          7064        7064          1992              6            2
# 11          7065        7065          1992              6            2
#
# ...

# %%
def minusday(x):
    if x.hour == 22:
        return x - datetime.timedelta(days = 1)
    return x

df["datetime"] = df["datetime"].apply(minusday)

# %%
df.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0  year (local)  month (local)  day (local)  \
# 0          7054        7054          1992              6            1
# 1          7055        7055          1992              6            1
# 2          7056        7056          1992              6            1
# 3          7057        7057          1992              6            1
# 4          7058        7058          1992              6            1
# 5          7059        7059          1992              6            1
# 6          7060        7060          1992              6            1
# 7          7061        7061          1992              6            1
# 8          7062        7062          1992              6            2
# 9          7063        7063          1992              6            2
#
#    local time  total cloud cover  weather between time  wind direction  \
# 0          22                7.0                   2.0           240.0
# ...

# %%
df["date"] = df["datetime"].apply(lambda x : x.strftime("%Y-%m-%d"))
df = df.drop(["year (local)", "month (local)", "day (local)", "local time", "Unnamed: 0.1", "Unnamed: 0"], axis=1)

df.head()
# Out:
#    total cloud cover  weather between time  wind direction  \
# 0                7.0                   2.0           240.0
# 1                6.0                   2.0            90.0
# 2               10.0                   2.0           180.0
# 3                8.0                   2.0           300.0
# 4                8.0                   2.0           230.0
#
#    average wind speed  total precipitation  air temperature (dry termometer)  \
# 0                 1.0                  0.0                              16.4
# 1                 2.0                  0.0                              15.0
# 2                 1.0                  0.0                              13.8
# 3                 1.0                  0.0                              14.5
# 4                 2.0                  0.0                              20.4
#
#    relative air humidity  atmospheric pressure (station level)  \
# 0                   66.0                                 993.0
# ...

# %%
df.index = df['date']
df = df.drop(["date"], axis = 1)
df.head()
# Out:
#             total cloud cover  weather between time  wind direction  \
# date
# 1992-05-31                7.0                   2.0           240.0
# 1992-06-01                6.0                   2.0            90.0
# 1992-06-01               10.0                   2.0           180.0
# 1992-06-01                8.0                   2.0           300.0
# 1992-06-01                8.0                   2.0           230.0
#
#             average wind speed  total precipitation  \
# date
# 1992-05-31                 1.0                  0.0
# 1992-06-01                 2.0                  0.0
# 1992-06-01                 1.0                  0.0
# 1992-06-01                 1.0                  0.0
# 1992-06-01                 2.0                  0.0
#
#             air temperature (dry termometer)  relative air humidity  \
# date
# 1992-05-31                              16.4                   66.0
# 1992-06-01                              15.0                   68.0
# ...

# %%
sun = pd.read_csv("sun\sun_data.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\yayahearts\AppData\Local\Temp\ipykernel_13512\810220478.py:1: SyntaxWarning: invalid escape sequence '\s'
#   sun = pd.read_csv("sun\sun_data.csv")

# %%
sun.index = sun["date"]
sun = sun.drop(["date"], axis=1)
sun.head()
# Out:
#             Unnamed: 0      dawn   sunrise      noon    sunset      dusk
# date
# 1990-01-01           0  07:45:46  08:31:34  12:09:54  15:48:48  16:34:37
# 1990-01-02           1  07:45:39  08:31:21  12:10:22  15:49:59  16:35:41
# 1990-01-03           2  07:45:28  08:31:04  12:10:50  15:51:12  16:36:48
# 1990-01-04           3  07:45:15  08:30:43  12:11:18  15:52:30  16:37:58
# 1990-01-05           4  07:44:57  08:30:18  12:11:45  15:53:50  16:39:11

# %%
dfsun = df.join(sun, how = "inner")

# %%
dfsun.head(12)
# Out:
#             total cloud cover  weather between time  wind direction  \
# date
# 1992-05-31                7.0                   2.0           240.0
# 1992-06-01                6.0                   2.0            90.0
# 1992-06-01               10.0                   2.0           180.0
# 1992-06-01                8.0                   2.0           300.0
# 1992-06-01                8.0                   2.0           230.0
# 1992-06-01                4.0                   1.0           280.0
# 1992-06-01                4.0                   1.0           350.0
# 1992-06-01               10.0                   1.0           340.0
# 1992-06-01                5.0                   8.0             0.0
# 1992-06-02                0.0                   0.0            75.0
# 1992-06-02                1.0                   0.0           280.0
# 1992-06-02                6.0                   1.0           270.0
#
#             average wind speed  total precipitation  \
# date
# ...

# %%
#dfsun.to_csv("DFSUN.csv")

# %%
dfsun.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 89060 entries, 1992-05-31 to 2022-11-23
# Data columns (total 15 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   total cloud cover                     89060 non-null  float64
#  1   weather between time                  89060 non-null  float64
#  2   wind direction                        89060 non-null  float64
#  3   average wind speed                    89060 non-null  float64
#  4   total precipitation                   89060 non-null  float64
#  5   air temperature (dry termometer)      89060 non-null  float64
#  6   relative air humidity                 89060 non-null  float64
#  7   atmospheric pressure (station level)  89060 non-null  float64
#  8   datetime                              89060 non-null  datetime64[ns]
#  9   Unnamed: 0                            89060 non-null  int64
# ...

# %%
coo = pd.read_csv("co2_value_notNaN.csv")
coo.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  year  month  day  hour  minute  second  \
# 0             0           0  1975      7   24     4       0       0
# 1             1           1  1975      7   24     5       0       0
# 2             2           2  1975      7   24     6       0       0
# 3             3           3  1975      7   24     7       0       0
# 4             4           4  1975      7   24     8       0       0
#
#               datetime   value  nvalue instrument qcflag
# 0  1975-07-24 04:00:00  375.73       0      UN2-2    *..
# 1  1975-07-24 05:00:00  375.73       0      UN2-2    *..
# 2  1975-07-24 06:00:00  369.28       0      UN2-2    *..
# 3  1975-07-24 07:00:00  362.84       0      UN2-2    *..
# 4  1975-07-24 08:00:00  356.39       0      UN2-2    *..

# %%
coo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430158 entries, 0 to 430157
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0.1  430158 non-null  int64
#  1   Unnamed: 0    430158 non-null  int64
#  2   year          430158 non-null  int64
#  3   month         430158 non-null  int64
#  4   day           430158 non-null  int64
#  5   hour          430158 non-null  int64
#  6   minute        430158 non-null  int64
#  7   second        430158 non-null  int64
#  8   datetime      430158 non-null  object
#  9   value         430158 non-null  float64
#  10  nvalue        430158 non-null  int64
#  11  instrument    430158 non-null  object
#  12  qcflag        430158 non-null  object
# dtypes: float64(1), int64(9), object(3)
# memory usage: 42.7+ MB

# %%
coo['datetime'] = pd.to_datetime(coo['datetime'])

# %%
coo["date"] = coo["datetime"].apply(lambda x : x.strftime("%Y-%m-%d"))
coo = coo.drop(["year", "month", "day", "hour", "Unnamed: 0.1", "Unnamed: 0"], axis=1)

coo.head()
# Out:
#    minute  second            datetime   value  nvalue instrument qcflag  \
# 0       0       0 1975-07-24 04:00:00  375.73       0      UN2-2    *..
# 1       0       0 1975-07-24 05:00:00  375.73       0      UN2-2    *..
# 2       0       0 1975-07-24 06:00:00  369.28       0      UN2-2    *..
# 3       0       0 1975-07-24 07:00:00  362.84       0      UN2-2    *..
# 4       0       0 1975-07-24 08:00:00  356.39       0      UN2-2    *..
#
#          date
# 0  1975-07-24
# 1  1975-07-24
# 2  1975-07-24
# 3  1975-07-24
# 4  1975-07-24

# %%
coo = coo.drop(["instrument", "qcflag"], axis=1)
coo.head()
# Out:
#    minute  second            datetime   value  nvalue        date
# 0       0       0 1975-07-24 04:00:00  375.73       0  1975-07-24
# 1       0       0 1975-07-24 05:00:00  375.73       0  1975-07-24
# 2       0       0 1975-07-24 06:00:00  369.28       0  1975-07-24
# 3       0       0 1975-07-24 07:00:00  362.84       0  1975-07-24
# 4       0       0 1975-07-24 08:00:00  356.39       0  1975-07-24

# %%
coo.index = coo['date']
coo = coo.drop(["date", "second", "minute"], axis = 1)
coo.head(30)
# Out:
#                       datetime   value  nvalue
# date
# 1975-07-24 1975-07-24 04:00:00  375.73       0
# 1975-07-24 1975-07-24 05:00:00  375.73       0
# 1975-07-24 1975-07-24 06:00:00  369.28       0
# 1975-07-24 1975-07-24 07:00:00  362.84       0
# 1975-07-24 1975-07-24 08:00:00  356.39       0
# 1975-07-24 1975-07-24 09:00:00  349.95       0
# 1975-07-24 1975-07-24 10:00:00  343.50       0
# 1975-07-24 1975-07-24 11:00:00  337.06       0
# 1975-07-24 1975-07-24 12:00:00  330.61       0
# 1975-07-24 1975-07-24 13:00:00  330.61       1
# 1975-07-24 1975-07-24 14:00:00  329.62       1
# 1975-07-24 1975-07-24 15:00:00  329.16       1
# 1975-07-24 1975-07-24 16:00:00  330.23       1
# 1975-07-24 1975-07-24 17:00:00  331.84       1
# 1975-07-24 1975-07-24 18:00:00  331.42       1
# 1975-07-24 1975-07-24 19:00:00  331.41       1
# 1975-07-24 1975-07-24 20:00:00  330.55       1
# 1975-07-24 1975-07-24 21:00:00  329.52       1
# 1975-07-24 1975-07-24 22:00:00  328.13       1
# ...

# %%
coo.loc["1992-05-31"]
# Out:
#                       datetime   value  nvalue
# date
# 1992-05-31 1992-05-31 00:00:00  363.37       1
# 1992-05-31 1992-05-31 01:00:00  363.31       1
# 1992-05-31 1992-05-31 02:00:00  363.40       1
# 1992-05-31 1992-05-31 03:00:00  363.40       1
# 1992-05-31 1992-05-31 04:00:00  363.30       1
# 1992-05-31 1992-05-31 05:00:00  363.38       1
# 1992-05-31 1992-05-31 06:00:00  363.38       1
# 1992-05-31 1992-05-31 07:00:00  363.44       1
# 1992-05-31 1992-05-31 08:00:00  363.41       1
# 1992-05-31 1992-05-31 09:00:00  363.50       1
# 1992-05-31 1992-05-31 10:00:00  363.46       1
# 1992-05-31 1992-05-31 11:00:00  363.52       1
# 1992-05-31 1992-05-31 12:00:00  363.60       1
# 1992-05-31 1992-05-31 13:00:00  363.54       1
# 1992-05-31 1992-05-31 14:00:00  363.61       1
# 1992-05-31 1992-05-31 15:00:00  363.50       1
# 1992-05-31 1992-05-31 16:00:00  363.50       1
# 1992-05-31 1992-05-31 17:00:00  363.48       1
# 1992-05-31 1992-05-31 18:00:00  363.39       1
# ...

# %%
dfsun.head()
# Out:
#             total cloud cover  weather between time  wind direction  \
# date
# 1992-05-31                7.0                   2.0           240.0
# 1992-06-01                6.0                   2.0            90.0
# 1992-06-01               10.0                   2.0           180.0
# 1992-06-01                8.0                   2.0           300.0
# 1992-06-01                8.0                   2.0           230.0
#
#             average wind speed  total precipitation  \
# date
# 1992-05-31                 1.0                  0.0
# 1992-06-01                 2.0                  0.0
# 1992-06-01                 1.0                  0.0
# 1992-06-01                 1.0                  0.0
# 1992-06-01                 2.0                  0.0
#
#             air temperature (dry termometer)  relative air humidity  \
# date
# 1992-05-31                              16.4                   66.0
# 1992-06-01                              15.0                   68.0
# ...

# %%
dfsuncoo = dfsun.join(coo[["value", "nvalue"]], how = "left")
dfsuncoo.head()
# Out:
#             total cloud cover  weather between time  wind direction  \
# date
# 1992-05-31                7.0                   2.0           240.0
# 1992-05-31                7.0                   2.0           240.0
# 1992-05-31                7.0                   2.0           240.0
# 1992-05-31                7.0                   2.0           240.0
# 1992-05-31                7.0                   2.0           240.0
#
#             average wind speed  total precipitation  \
# date
# 1992-05-31                 1.0                  0.0
# 1992-05-31                 1.0                  0.0
# 1992-05-31                 1.0                  0.0
# 1992-05-31                 1.0                  0.0
# 1992-05-31                 1.0                  0.0
#
#             air temperature (dry termometer)  relative air humidity  \
# date
# 1992-05-31                              16.4                   66.0
# 1992-05-31                              16.4                   66.0
# ...

# %%
print(dfsun["datetime"].iloc[0], dfsun["datetime"].iloc[89059])
# Out:
# 1992-05-31 22:00:00 2022-11-23 07:00:00

# %%
dtlist = list(dfsun["datetime"])
dtlist[:2]
# Out:
# [Timestamp('1992-05-31 22:00:00'), Timestamp('1992-06-01 01:00:00')]

# %%
co2vals = []
for i in range(len(coo)):
    if coo["datetime"].iloc[i] in dtlist:
        co2vals.append({coo["datetime"].iloc[i]: [coo["value"].iloc[i], coo["nvalue"].iloc[i]]})
co2vals[:2]
# Out:
# [{Timestamp('1992-05-31 22:00:00'): [363.39, 1]},
#  {Timestamp('1992-06-01 01:00:00'): [363.33, 1]}]

# %%
len(co2vals)
# Out:
# 89060

# %%
vals, nvals = [], []
for i in range(len(co2vals)):
    d = co2vals[i]
    k = list(d.keys())[0]
    v = list(d.values())[0]
    vals.append(v[0])
    nvals.append(v[1])
print(vals[:2], nvals[:2])
# Out:
# [363.39, 363.33] [1, 1]

# %%
dfun = dfsun.copy(deep=True)

# %%
dfun["value"] = vals
dfun["nvalue"] = nvals
dfun
# Out:
#             total cloud cover  weather between time  wind direction  \
# date
# 1992-05-31                7.0                   2.0           240.0
# 1992-06-01                6.0                   2.0            90.0
# 1992-06-01               10.0                   2.0           180.0
# 1992-06-01                8.0                   2.0           300.0
# 1992-06-01                8.0                   2.0           230.0
# ...                       ...                   ...             ...
# 2022-11-22               10.0                   7.0           107.0
# 2022-11-22               10.0                   7.0           106.0
# 2022-11-23               10.0                   7.0           118.0
# 2022-11-23               10.0                   7.0             0.0
# 2022-11-23               10.0                   6.0            90.0
#
#             average wind speed  total precipitation  \
# date
# 1992-05-31                 1.0                  0.0
# ...

# %%
dfun.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 89060 entries, 1992-05-31 to 2022-11-23
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   total cloud cover                     89060 non-null  float64
#  1   weather between time                  89060 non-null  float64
#  2   wind direction                        89060 non-null  float64
#  3   average wind speed                    89060 non-null  float64
#  4   total precipitation                   89060 non-null  float64
#  5   air temperature (dry termometer)      89060 non-null  float64
#  6   relative air humidity                 89060 non-null  float64
#  7   atmospheric pressure (station level)  89060 non-null  float64
#  8   datetime                              89060 non-null  datetime64[ns]
#  9   dawn                                  89060 non-null  object
# ...

# %%
dfun.drop("Unnamed: 0", axis=1, inplace=True)
dfun
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 dfun.drop("Unnamed: 0", axis=1, inplace=True)
#       2 dfun
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
dfun.to_csv("meteo_all_joined_raw.csv")

# %%
type(dfun["datetime"][0])
# Out:
# C:\Users\yayahearts\AppData\Local\Temp\ipykernel_13512\3142325569.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   type(dfun["datetime"][0])
# pandas._libs.tslibs.timestamps.Timestamp

# %%
type(dfun["datetime"][i].hour)
# Out:
# C:\Users\yayahearts\AppData\Local\Temp\ipykernel_13512\3044597800.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   type(dfun["datetime"][i].hour)
# int

# %%
print((int)(dfun["sunset"].iloc[i][0] + dfun["sunset"].iloc[i][1]))
# Out:
# 21

# %%
isday = []
for i in range(len(dfun)):
    if ((int)(dfun["sunrise"].iloc[i][0] + dfun["sunrise"].iloc[i][1]) + 1 <= dfun["datetime"][i].hour <= (int)(dfun["sunset"].iloc[i][0] + dfun["sunset"].iloc[i][1])):
        isday.append(1)
    else:
        isday.append(0)
# Out:
# C:\Users\yayahearts\AppData\Local\Temp\ipykernel_13512\2560469.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ((int)(dfun["sunrise"].iloc[i][0] + dfun["sunrise"].iloc[i][1]) + 1 <= dfun["datetime"][i].hour <= (int)(dfun["sunset"].iloc[i][0] + dfun["sunset"].iloc[i][1])):

# %%
isday = []
for i in range(len(dfun)):
    if (int(dfun["sunrise"].iloc[i][0] + dfun["sunrise"].iloc[i][1]) + 1 <= dfun["datetime"][i].hour <= int(dfun["sunset"].iloc[i][0] + dfun["sunset"].iloc[i][1])):
       isday.append(1)
    else:
       isday.append(0)
dfun["isday"] =isday
dfun.head()
# Out:
# C:\Users\yayahearts\AppData\Local\Temp\ipykernel_13512\2153056342.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (int(dfun["sunrise"].iloc[i][0] + dfun["sunrise"].iloc[i][1]) + 1 <= dfun["datetime"][i].hour <= int(dfun["sunset"].iloc[i][0] + dfun["sunset"].iloc[i][1])):
#             total cloud cover  weather between time  wind direction  \
# date
# 1992-05-31                7.0                   2.0           240.0
# 1992-06-01                6.0                   2.0            90.0
# 1992-06-01               10.0                   2.0           180.0
# 1992-06-01                8.0                   2.0           300.0
# 1992-06-01                8.0                   2.0           230.0
#
#             average wind speed  total precipitation  \
# date
# ...

# %%
dfun = dfun.drop(["dawn", "sunrise", "noon", "dusk", "sunset"], axis = 1)
dfun.head()
# Out:
#             total cloud cover  weather between time  wind direction  \
# date
# 1992-05-31                7.0                   2.0           240.0
# 1992-06-01                6.0                   2.0            90.0
# 1992-06-01               10.0                   2.0           180.0
# 1992-06-01                8.0                   2.0           300.0
# 1992-06-01                8.0                   2.0           230.0
#
#             average wind speed  total precipitation  \
# date
# 1992-05-31                 1.0                  0.0
# 1992-06-01                 2.0                  0.0
# 1992-06-01                 1.0                  0.0
# 1992-06-01                 1.0                  0.0
# 1992-06-01                 2.0                  0.0
#
#             air temperature (dry termometer)  relative air humidity  \
# date
# 1992-05-31                              16.4                   66.0
# 1992-06-01                              15.0                   68.0
# ...

# %%
dfun = pd.read_csv("meteo_all_joined_complete.csv")

# %%
dfun.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89060 entries, 0 to 89059
# Data columns (total 13 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   date                                  89060 non-null  object
#  1   total cloud cover                     89060 non-null  float64
#  2   weather between time                  89060 non-null  float64
#  3   wind direction                        89060 non-null  float64
#  4   average wind speed                    89060 non-null  float64
#  5   total precipitation                   89060 non-null  float64
#  6   air temperature (dry termometer)      89060 non-null  float64
#  7   relative air humidity                 89060 non-null  float64
#  8   atmospheric pressure (station level)  89060 non-null  float64
#  9   datetime                              89060 non-null  object
# ...

# %%
dfun.index = dfun["datetime"]

# %%
dfun.head()
dfun = dfun.drop(["datetime", "date"], axis = 1)

# %%
dfun.head()
# Out:
#                      total cloud cover  weather between time  wind direction  \
# datetime
# 1992-05-31 22:00:00                7.0                   2.0           240.0
# 1992-06-01 01:00:00                6.0                   2.0            90.0
# 1992-06-01 04:00:00               10.0                   2.0           180.0
# 1992-06-01 07:00:00                8.0                   2.0           300.0
# 1992-06-01 10:00:00                8.0                   2.0           230.0
#
#                      average wind speed  total precipitation  \
# datetime
# 1992-05-31 22:00:00                 1.0                  0.0
# 1992-06-01 01:00:00                 2.0                  0.0
# 1992-06-01 04:00:00                 1.0                  0.0
# 1992-06-01 07:00:00                 1.0                  0.0
# 1992-06-01 10:00:00                 2.0                  0.0
#
#                      air temperature (dry termometer)  relative air humidity  \
# datetime
# ...

# %%
dfun = dfun.drop(["nvalue"], axis = 1)

# %%
dfun.to_csv("meteo_all_joined_complete.csv")

# %%
dfun = pd.read_csv("meteo_all_joined_complete.csv")

# %%
dfun.shape
# Out:
# (89060, 11)

# %%
ind = []
for i in range(1, 89061):
    ind.append(i)
dfun.index = ind
dfun.head()
# Out:
#               datetime  total cloud cover  weather between time  \
# 1  1992-05-31 22:00:00                7.0                   2.0
# 2  1992-06-01 01:00:00                6.0                   2.0
# 3  1992-06-01 04:00:00               10.0                   2.0
# 4  1992-06-01 07:00:00                8.0                   2.0
# 5  1992-06-01 10:00:00                8.0                   2.0
#
#    wind direction  average wind speed  total precipitation  \
# 1           240.0                 1.0                  0.0
# 2            90.0                 2.0                  0.0
# 3           180.0                 1.0                  0.0
# 4           300.0                 1.0                  0.0
# 5           230.0                 2.0                  0.0
#
#    air temperature (dry termometer)  relative air humidity  \
# 1                              16.4                   66.0
# 2                              15.0                   68.0
# ...

# %%
dfun = dfun.drop(["datetime"], axis = 1)

# %%
dfun.head()
# Out:
#    total cloud cover  weather between time  wind direction  \
# 1                7.0                   2.0           240.0
# 2                6.0                   2.0            90.0
# 3               10.0                   2.0           180.0
# 4                8.0                   2.0           300.0
# 5                8.0                   2.0           230.0
#
#    average wind speed  total precipitation  air temperature (dry termometer)  \
# 1                 1.0                  0.0                              16.4
# 2                 2.0                  0.0                              15.0
# 3                 1.0                  0.0                              13.8
# 4                 1.0                  0.0                              14.5
# 5                 2.0                  0.0                              20.4
#
#    relative air humidity  atmospheric pressure (station level)   value  isday
# ...

# %%
dfun.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 89060 entries, 1 to 89060
# Data columns (total 10 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   total cloud cover                     89060 non-null  float64
#  1   weather between time                  89060 non-null  float64
#  2   wind direction                        89060 non-null  float64
#  3   average wind speed                    89060 non-null  float64
#  4   total precipitation                   89060 non-null  float64
#  5   air temperature (dry termometer)      89060 non-null  float64
#  6   relative air humidity                 89060 non-null  float64
#  7   atmospheric pressure (station level)  89060 non-null  float64
#  8   value                                 89060 non-null  float64
#  9   isday                                 89060 non-null  int64
# dtypes: float64(9), int64(1)
# memory usage: 7.5 MB

# %%
for i in range(0, 89061):
    if dfun["total precipitation"][i] == 0.0:
         dfun["total precipitation"][i] = 0.0
    else:
        dfun["total precipitation"][i] = 1.0
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 2
#       1 for i in range(0, 89061):
# ...

# %%
coo[""] = coo["datetime"].apply(lambda x : x
coo = coo.drop(["year", "month", "day", "hour", "Unnamed: 0.1", "Unnamed: 0"], axis=1)

coo.head()

# %%
dfun['is_precipitation'] = dfun.apply(lambda x: 1 if (x["total precipitation"] > 0) else 0, axis=1)

# %%
dfun["is_precipitation"] == dfun["precipitation false"]
# Out:
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 89056    False
# 89057    False
# 89058    False
# 89059    False
# 89060    False
# Length: 89060, dtype: bool

# %%
dfun.head()
# Out:
#    total cloud cover  weather between time  average wind speed  \
# 1                7.0                   2.0                 1.0
# 2                6.0                   2.0                 2.0
# 3               10.0                   2.0                 1.0
# 4                8.0                   2.0                 1.0
# 5                8.0                   2.0                 2.0
#
#    air temperature (dry termometer)  relative air humidity  \
# 1                              16.4                   66.0
# 2                              15.0                   68.0
# 3                              13.8                   73.0
# 4                              14.5                   76.0
# 5                              20.4                   52.0
#
#    atmospheric pressure (station level)   value  day  night  \
# 1                                 993.0  363.39    0      1
# 2                                 992.5  363.33    0      1
# ...

# %%
dfun = dfun.drop(["is_precipitation", "isday"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 dfun = dfun.drop(["is_precipitation", "isday"], axis=1)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
day = []
night = []
for i in range(len(dfun)):
    day.append(dfun["is_precipitation"].iloc[i])
    night.append(1-dfun["is_precipitation"].iloc[i])
dfun["precipitation true"] = day
dfun["precipitation false"] = night

# %%
dfun.to_csv("meteo_ready_unsplitted.csv")

# %%
dfun_s = dfun.sample(frac=1)
dfun_s.head(20)
# Out:
#        total cloud cover  weather between time  wind direction  \
# 77508               10.0                   7.0           140.0
# 50810                0.0                   0.0           270.0
# 20907               10.0                   2.0            55.0
# 59219                4.0                   1.0           230.0
# 22753               10.0                   1.0           200.0
# 45194                9.0                   8.0           310.0
# 24591               10.0                   7.0            70.0
# 39004                6.0                   2.0            15.0
# 25412               10.0                   2.0           220.0
# 10333               10.0                   7.0           280.0
# 23392               12.0                   2.0           310.0
# 86283                0.0                   0.0            65.0
# 65476               10.0                   2.0           240.0
# 84491               10.0                   2.0           185.0
# ...

# %%
df_train, df_test = dfun_s.iloc[:80154], dfun_s.iloc[80154:]

# %%
means = []
for i in dfun_s:
    means.append((df_train[i].mean(), df_test[i].mean()))
means
# Out:
# [(7.314706689622477, 7.38681787558949),
#  (3.16821368864935, 3.178194475634404),
#  (1.9328542555580508, 1.9553110262744218),
#  (5.436132944082641, 5.652717269256681),
#  (75.07017740848866, 74.89467774534022),
#  (996.2082778152057, 996.0796204805748),
#  (386.6860147965167, 386.96140354816976),
#  (0.4983531701474661, 0.516281158769369),
#  (0.5016468298525338, 0.483718841230631),
#  (0.08627142750205853, 0.08847967662250168),
#  (0.9137285724979415, 0.9115203233774983)]

# %%
for x, y in means:
    print(abs(x-y))
# Out:
# 0.07211118596701382
# 0.009980786985053669
# 0.022456770716370977
# 0.2165843251740398
# 0.17549966314844312
# 0.12865733463092965
# 0.275388751653054
# 0.01792798862190287
# 0.017927988621902813
# 0.002208249120443151
# 0.002208249120443151
